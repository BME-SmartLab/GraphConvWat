# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(os.path.join('..', 'experiments', 'Taylor_metrics.csv'), header=None)
df.head(3)
# Out:
#                                        0           1          2
# 0  anytown-fixrnd-0.05-binary-def-1-orig  329.145719  18.142374
# 1   anytown-fixrnd-0.05-binary-def-1-gcn  305.902143  17.431887
# 2   anytown-fixrnd-0.05-binary-def-2-gcn  289.265015  16.723429

# %%
df.columns = ['run_id', 'MSEc', 'sigma_pred']
df['sigma_true'] = 0
df['seed'] = 0
df['wds'] = [elem.split('-')[0] for elem in df['run_id']]
df['placement'] = [elem.split('-')[1] for elem in df['run_id']]
df['obs_rat'] = [elem.split('-')[2] for elem in df['run_id']]
df['adjacency'] = [elem.split('-')[3] for elem in df['run_id']]
df['tag'] = [elem.split('-')[4] for elem in df['run_id']]
df['num'] = [elem.split('-')[5] for elem in df['run_id']]
df['model'] = [elem.split('-')[6] for elem in df['run_id']]

# %%
df.head(3)
# Out:
#                                   run_id        MSEc  sigma_pred  sigma_true  \
# 0  anytown-fixrnd-0.05-binary-def-1-orig  329.145719   18.142374           0
# 1   anytown-fixrnd-0.05-binary-def-1-gcn  305.902143   17.431887           0
# 2   anytown-fixrnd-0.05-binary-def-2-gcn  289.265015   16.723429           0
#
#    seed      wds placement obs_rat adjacency  tag num model
# 0     0  anytown    fixrnd    0.05    binary  def   1  orig
# 1     0  anytown    fixrnd    0.05    binary  def   1   gcn
# 2     0  anytown    fixrnd    0.05    binary  def   2   gcn

# %%
for wds in df['wds'].unique():
    sigma_true = df['sigma_pred'][(df['wds'] == wds) & (df['model'] == 'orig')].tolist()[0]
    df.loc[df['wds'] == wds, 'sigma_true'] = sigma_true

# %%
df.head()
# Out:
#                                   run_id        MSEc  sigma_pred  sigma_true  \
# 0  anytown-fixrnd-0.05-binary-def-1-orig  329.145719   18.142374   18.142374
# 1   anytown-fixrnd-0.05-binary-def-1-gcn  305.902143   17.431887   18.142374
# 2   anytown-fixrnd-0.05-binary-def-2-gcn  289.265015   16.723429   18.142374
# 3   anytown-fixrnd-0.05-binary-def-3-gcn  274.175302   16.311682   18.142374
# 4   anytown-fixrnd-0.05-binary-def-4-gcn  277.586525   16.270504   18.142374
#
#    seed      wds placement obs_rat adjacency  tag num model
# 0     0  anytown    fixrnd    0.05    binary  def   1  orig
# 1     0  anytown    fixrnd    0.05    binary  def   1   gcn
# 2     0  anytown    fixrnd    0.05    binary  def   2   gcn
# 3     0  anytown    fixrnd    0.05    binary  def   3   gcn
# 4     0  anytown    fixrnd    0.05    binary  def   4   gcn

# %%
df['corr_coeff'] = df['MSEc'] / (df['sigma_true']*df['sigma_pred'])

# %% [markdown]
# ### Handling results from sensor placement with random seeds

# %%
seeds = np.array([1, 8, 5266, 739, 88867])
mask = df['placement'] == 'random'
df.loc[mask, 'seed'] = seeds[df.loc[mask, 'num'].values.astype(int) % len(seeds)]

# %%
df.tail(10)
# Out:
#                                           run_id        MSEc  sigma_pred  \
# 1207   anytown-random-0.1-binary-placement-6-gcn  269.914002   16.130374
# 1208   anytown-random-0.1-binary-placement-7-gcn  252.807174   15.617175
# 1209   anytown-random-0.1-binary-placement-8-gcn  304.977537   17.270471
# 1210   anytown-random-0.1-binary-placement-9-gcn  251.655223   15.614562
# 1211  anytown-random-0.1-binary-placement-10-gcn  311.906576   17.685187
# 1212  anytown-random-0.1-binary-placement-11-gcn  270.901425   16.180567
# 1213  anytown-random-0.1-binary-placement-12-gcn  252.849335   15.588022
# 1214  anytown-random-0.1-binary-placement-13-gcn  306.848826   17.357897
# 1215  anytown-random-0.1-binary-placement-14-gcn  249.345590   15.480686
# 1216  anytown-random-0.1-binary-placement-15-gcn  311.994824   17.674226
#
#       sigma_true   seed      wds placement obs_rat adjacency        tag num  \
# 1207   18.142374      8  anytown    random     0.1    binary  placement   6
# 1208   18.142374   5266  anytown    random     0.1    binary  placement   7
# 1209   18.142374    739  anytown    random     0.1    binary  placement   8
# 1210   18.142374  88867  anytown    random     0.1    binary  placement   9
# 1211   18.142374      1  anytown    random     0.1    binary  placement  10
# 1212   18.142374      8  anytown    random     0.1    binary  placement  11
# 1213   18.142374   5266  anytown    random     0.1    binary  placement  12
# 1214   18.142374    739  anytown    random     0.1    binary  placement  13
# 1215   18.142374  88867  anytown    random     0.1    binary  placement  14
# 1216   18.142374      1  anytown    random     0.1    binary  placement  15
#
#      model  corr_coeff
# 1207   gcn    0.922331
# 1208   gcn    0.892263
# 1209   gcn    0.973351
# 1210   gcn    0.888346
# 1211   gcn    0.972122
# 1212   gcn    0.922834
# 1213   gcn    0.894081
# 1214   gcn    0.974391
# 1215   gcn    0.887805
# 1216   gcn    0.973000

# %%
df.to_csv(os.path.join('..', 'experiments', 'Taylor_metrics_processed.csv'))
