# %%
import os
import pandas as pd

# %%
df = pd.read_csv(os.path.join('..', 'experiments', 'Taylor_metrics.csv'), header=None)
df.head(3)
# Out:
#                                            0           1          2
# 0      anytown-fixrnd-0.05-binary-def-1-orig  329.145719  18.142374
# 1  anytown-random-0.1-binary-placement-1-gcn  310.458536  17.585783
# 2  anytown-random-0.1-binary-placement-2-gcn  267.512504  16.007248

# %%
df.columns = ['run_id', 'MSEc', 'sigma_pred']
df['sigma_true'] = 0
df['wds'] = [elem.split('-')[0] for elem in df['run_id']]
df['placement'] = [elem.split('-')[1] for elem in df['run_id']]
df['obs_rat'] = [elem.split('-')[2] for elem in df['run_id']]
df['adjacency'] = [elem.split('-')[3] for elem in df['run_id']]
df['tag'] = [elem.split('-')[4] for elem in df['run_id']]
df['num'] = [elem.split('-')[5] for elem in df['run_id']]
df['model'] = [elem.split('-')[6] for elem in df['run_id']]

# %%
df.head(3)
# Out:
#                                       run_id        MSEc  sigma_pred  \
# 0      anytown-fixrnd-0.05-binary-def-1-orig  329.145719   18.142374
# 1  anytown-random-0.1-binary-placement-1-gcn  310.458536   17.585783
# 2  anytown-random-0.1-binary-placement-2-gcn  267.512504   16.007248
#
#    sigma_true      wds placement obs_rat adjacency        tag num model
# 0           0  anytown    fixrnd    0.05    binary        def   1  orig
# 1           0  anytown    random     0.1    binary  placement   1   gcn
# 2           0  anytown    random     0.1    binary  placement   2   gcn

# %%
for wds in df['wds'].unique():
    sigma_true = df['sigma_pred'][(df['wds'] == wds) & (df['model'] == 'orig')].tolist()[0]
    df.loc[df['wds'] == wds, 'sigma_true'] = sigma_true

# %%
df.head()
# Out:
#                                       run_id        MSEc  sigma_pred  \
# 0      anytown-fixrnd-0.05-binary-def-1-orig  329.145719   18.142374
# 1  anytown-random-0.1-binary-placement-1-gcn  310.458536   17.585783
# 2  anytown-random-0.1-binary-placement-2-gcn  267.512504   16.007248
# 3  anytown-random-0.1-binary-placement-3-gcn  253.107829   15.635904
# 4  anytown-random-0.1-binary-placement-4-gcn  267.604985   15.989566
#
#    sigma_true      wds placement obs_rat adjacency        tag num model
# 0   18.142374  anytown    fixrnd    0.05    binary        def   1  orig
# 1   18.142374  anytown    random     0.1    binary  placement   1   gcn
# 2   18.142374  anytown    random     0.1    binary  placement   2   gcn
# 3   18.142374  anytown    random     0.1    binary  placement   3   gcn
# 4   18.142374  anytown    random     0.1    binary  placement   4   gcn

# %%
df['corr_coeff'] = df['MSEc'] / (df['sigma_true']*df['sigma_pred'])

# %%
df.head()
# Out:
#                                       run_id        MSEc  sigma_pred  \
# 0      anytown-fixrnd-0.05-binary-def-1-orig  329.145719   18.142374
# 1  anytown-random-0.1-binary-placement-1-gcn  310.458536   17.585783
# 2  anytown-random-0.1-binary-placement-2-gcn  267.512504   16.007248
# 3  anytown-random-0.1-binary-placement-3-gcn  253.107829   15.635904
# 4  anytown-random-0.1-binary-placement-4-gcn  267.604985   15.989566
#
#    sigma_true      wds placement obs_rat adjacency        tag num model  \
# 0   18.142374  anytown    fixrnd    0.05    binary        def   1  orig
# 1   18.142374  anytown    random     0.1    binary  placement   1   gcn
# 2   18.142374  anytown    random     0.1    binary  placement   2   gcn
# 3   18.142374  anytown    random     0.1    binary  placement   3   gcn
# 4   18.142374  anytown    random     0.1    binary  placement   4   gcn
#
#    corr_coeff
# 0    1.000000
# 1    0.973078
# 2    0.921156
# 3    0.892254
# 4    0.922494

# %%
df.to_csv(os.path.join('..', 'experiments', 'Taylor_metrics_processed.csv'))
